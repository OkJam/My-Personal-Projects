# %%
# Import necessary packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Import the data
ReliaData = pd.read_csv(r'C:\Users\James ok\Desktop\Desktop2\RELIABILITY_RESEARCH\ReliaDat.csv', parse_dates=['date'], index_col = ['date'])

#Add to data frame and print the first 5 rows
ReliaData = pd.DataFrame(ReliaData)
ReliaData.head()
# Out:
#         IKENEGBU_SAIDI  CAIDI  SAIFI   ASAI   SAIDI  CAIDI.1  SAIFI.1  ASAI.1  \
# date
# Aug-17          112.16  54.30   2.07  98.46  304.30    30.43     10.0   95.83
# Sep-17          172.38   9.88  17.45  97.64  190.07    19.01     10.0   97.39
# Oct-17          366.58  21.01  17.45  94.98  486.04    48.60     10.0   93.34
# Nov-17          298.48  17.11  17.45  95.91  357.17    35.72     10.0   95.10
# Dec-17          209.35  12.00  17.45  97.13  439.25    43.92     10.0   93.98
#
#         SAIDI.1  CAIDI.2  ...  SAIFI.9  ASAI.9  SAIDI.9  CAIDI.10  SAIFI.10  \
# date                      ...
# Aug-17   683.35    68.34  ...     10.0   95.86   680.78     68.08      10.0
# Sep-17   711.50    71.15  ...     10.0   93.15   639.73     63.97      10.0
# Oct-17   743.82    74.38  ...     10.0   93.19   626.25     62.63      10.0
# Nov-17   720.00    72.00  ...     10.0   93.66   553.08     55.31      10.0
# Dec-17   689.15    68.92  ...     10.0   94.42   506.10     50.61      10.0
#
# ...

# %%
#Convert the np index to numpy (This will help us adjust the bar position)
X_axis = np.arange(len(ReliaData.index.values))

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(30, 35),)

w = 0.08

IKENEGBU = ReliaData['IKENEGBU_SAIDI']
FUT = ReliaData['SAIDI']
EGBU = ReliaData['SAIDI.1']
NEW_OWERRI = ReliaData['SAIDI.2']
NAZE = ReliaData['SAIDI.3']
GRA = ReliaData['SAIDI.4']
TOWNSHIP = ReliaData['SAIDI.5']
IFAKALA = ReliaData['SAIDI.6']
MBIERRI = ReliaData['SAIDI.7']
URLU = ReliaData['SAIDI.8']

# Add x-axis and y-axis
ax.barh(X_axis-0.5, IKENEGBU, w, color='w' , align='center', label = 'IKENEGBU',edgecolor = 'black',linewidth=3)
ax.barh(X_axis-0.42, FUT, w, color='g', align='center', hatch = '||', label = 'FUT',edgecolor = 'black',linewidth=3)
ax.barh(X_axis-0.34,EGBU , w, color='r', align='center',  hatch = '\\', label = 'EGBU',edgecolor = 'black',linewidth=3)
ax.barh(X_axis-0.26,NEW_OWERRI , w, color='b', align='center',  hatch = '*', label = 'NEW OWERRI',edgecolor = 'black',linewidth=3)
ax.barh(X_axis-0.18,NAZE , w, color='y', align='center',  hatch = 'O', label = 'NAZE',edgecolor = 'black',linewidth=3)
ax.barh(X_axis-0.1,GRA , w, color='0.8', align='center', hatch = '///', label = 'GRA',edgecolor = 'black',linewidth=3)
ax.barh(X_axis-0.02,TOWNSHIP , w, color='w', align='center', hatch = '+', label = 'TOWNSHIP',edgecolor = 'black',linewidth=3)
ax.barh(X_axis+0.06,IFAKALA, w, color='w', align='center', hatch = 'x', label = 'IFAKALA',edgecolor = 'black',linewidth=3)
ax.barh(X_axis+0.14,MBIERRI , w, color='c', align='center', hatch = 'oo', label = 'MBIERRI',edgecolor = 'black',linewidth=3)
ax.barh(X_axis+0.22,URLU, w, color='w', align='center', hatch = '/', label = 'URLU 33KVA',edgecolor = 'black',linewidth=3)
ax.set_axisbelow(True)

#Add only horizontal grid
ax.grid(which="major", axis='x')

#Define x and y ticks
major_tick = range(50,800, 50)
ax.set_xticks(major_tick) # Grid
plt.tick_params(labelsize=30,grid_linewidth=2)
plt.yticks(X_axis, ReliaData.index.values, fontsize = 30)

#Define x and y labels
plt.xlabel("SAIDI", fontsize = 30,fontweight='bold')
plt.ylabel("MONTHS",rotation=90, fontsize = 30,fontweight='bold')
#Add legend
plt.legend(loc="lower center", bbox_to_anchor=[0.5, -0.12],ncol=len(ReliaData.columns), shadow=False, title="LEGEND", fancybox=True, fontsize = 23)

plt.title("Figure 7: SAIDI (Comparative Monthly System Average Interruption Duration Index for the Study Period)", fontsize=35, y=-0.15)
plt.axis('tight')
plt.show()

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(35, 28),)

w = 0.08

IKENEGBU = ReliaData['CAIDI']
FUT = ReliaData['CAIDI.1']
EGBU = ReliaData['CAIDI.2']
NEW_OWERRI = ReliaData['CAIDI.3']
NAZE = ReliaData['CAIDI.4']
GRA = ReliaData['CAIDI.5']
TOWNSHIP = ReliaData['CAIDI.6']
IFAKALA = ReliaData['CAIDI.7']
MBIERRI = ReliaData['CAIDI.8']
URLU = ReliaData['CAIDI.9']

# Add x-axis and y-axis
ax.bar(X_axis-0.5, IKENEGBU, w, color='w' , align='center', label = 'IKENEGBU',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.42, FUT, w, color='w', align='center', hatch = '||', label = 'FUT',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.34,EGBU , w, color='w', align='center',  hatch = '\\', label = 'EGBU',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.26,NEW_OWERRI , w, color='w', align='center',  hatch = '*', label = 'NEW OWERRI',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.18,NAZE , w, color='w', align='center',  hatch = 'O', label = 'NAZE',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.1,GRA , w, color='w', align='center', hatch = '///', label = 'GRA',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.02,TOWNSHIP , w, color='w', align='center', hatch = '+', label = 'TOWNSHIP',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.06,IFAKALA, w, color='w', align='center', hatch = 'x', label = 'IFAKALA',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.14,MBIERRI , w, color='w', align='center', hatch = 'o', label = 'MBIERRI',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.22,URLU, w, color='w', align='center', hatch = '/', label = 'URLU 33KVA',edgecolor = 'black',linewidth=3)
ax.set_axisbelow(True)

#Add only horizontal grid
ax.grid(which="major", axis='x')

plt.xticks(X_axis, ReliaData.index.values, fontsize = 30)
plt.xlabel("DATE", fontsize = 30,fontweight='bold')
plt.ylabel("CAIDI", fontsize = 30,fontweight='bold')
plt.legend(loc="lower center", bbox_to_anchor=[0.5, -0.12],ncol=len(ReliaData.columns), shadow=False, title="LEGEND", fancybox=True, fontsize = 23)

plt.tick_params(labelsize=30,grid_linewidth=2)
major_tick = range(5,80, 5)
ax.set_yticks(major_tick) # Grid

plt.title("Figure 7: CAIDI (Comparative Monthly Customer Average Interruption Duration Index for the Study Period)", fontsize=35, y=-0.15)
plt.axis('tight')
plt.show()

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(35, 28),)

w = 0.08

IKENEGBU = ReliaData['SAIFI']
FUT = ReliaData['SAIFI.1']
EGBU = ReliaData['SAIFI.2']
NEW_OWERRI = ReliaData['SAIFI.3']
NAZE = ReliaData['SAIFI.4']
GRA = ReliaData['SAIFI.5']
TOWNSHIP = ReliaData['SAIFI.6']
IFAKALA = ReliaData['SAIFI.7']
MBIERRI = ReliaData['SAIFI.8']
URLU = ReliaData['SAIFI.9']

# Add x-axis and y-axis
ax.bar(X_axis-0.5, IKENEGBU, w, color='w' , align='center', label = 'IKENEGBU',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.42, FUT, w, color='w', align='center', hatch = '||', label = 'FUT',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.34,EGBU , w, color='w', align='center',  hatch = '\\', label = 'EGBU',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.26,NEW_OWERRI , w, color='w', align='center',  hatch = '*', label = 'NEW OWERRI',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.18,NAZE , w, color='w', align='center',  hatch = 'O', label = 'NAZE',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.1,GRA , w, color='w', align='center', hatch = '///', label = 'GRA',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.02,TOWNSHIP , w, color='w', align='center', hatch = '+', label = 'TOWNSHIP',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.06,IFAKALA, w, color='w', align='center', hatch = 'x', label = 'IFAKALA',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.14,MBIERRI , w, color='w', align='center', hatch = 'o', label = 'MBIERRI',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.22,URLU, w, color='w', align='center', hatch = '/', label = 'URLU 33KVA',edgecolor = 'black',linewidth=3)
ax.set_axisbelow(True)

#Add only horizontal grid
ax.grid(which="major", axis='x')

plt.xticks(X_axis, ReliaData.index.values, fontsize = 30)
plt.xlabel("DATE", fontsize = 30,fontweight='bold')
plt.ylabel("SAIFI", fontsize = 30,fontweight='bold')
plt.legend(loc="lower center", bbox_to_anchor=[0.5, -0.12],ncol=len(ReliaData.columns), shadow=False, title="LEGEND", fancybox=True, fontsize = 23)

plt.tick_params(labelsize=30,grid_linewidth=2)
major_tick = range(1,20, 1)
ax.set_yticks(major_tick) # Grid

plt.title("Figure 7: SAIFI (Comparative Monthly System Average Interruption Frequency Index for the Study Period)", fontsize=35, y=-0.15)
plt.axis('tight')
plt.show()

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(35, 28),)

w = 0.08

IKENEGBU = ReliaData['ASAI']
FUT = ReliaData['ASAI.1']
EGBU = ReliaData['ASAI.2']
NEW_OWERRI = ReliaData['ASAI.3']
NAZE = ReliaData['ASAI.4']
GRA = ReliaData['ASAI.5']
TOWNSHIP = ReliaData['ASAI.6']
IFAKALA = ReliaData['ASAI.7']
MBIERRI = ReliaData['ASAI.8']
URLU = ReliaData['ASAI.9']

# Add x-axis and y-axis
ax.bar(X_axis-0.5, IKENEGBU, w, color='w' , align='center', label = 'IKENEGBU',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.42, FUT, w, color='w', align='center', hatch = '||', label = 'FUT',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.34,EGBU , w, color='w', align='center',  hatch = '\\', label = 'EGBU',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.26,NEW_OWERRI , w, color='w', align='center',  hatch = '*', label = 'NEW OWERRI',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.18,NAZE , w, color='w', align='center',  hatch = 'O', label = 'NAZE',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.1,GRA , w, color='w', align='center', hatch = '///', label = 'GRA',edgecolor = 'black',linewidth=3)
ax.bar(X_axis-0.02,TOWNSHIP , w, color='w', align='center', hatch = '+', label = 'TOWNSHIP',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.06,IFAKALA, w, color='w', align='center', hatch = 'x', label = 'IFAKALA',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.14,MBIERRI , w, color='w', align='center', hatch = 'o', label = 'MBIERRI',edgecolor = 'black',linewidth=3)
ax.bar(X_axis+0.22,URLU, w, color='w', align='center', hatch = '/', label = 'URLU 33KVA',edgecolor = 'black',linewidth=3)
ax.set_axisbelow(True)

#Add only horizontal grid
ax.grid(which="major", axis='x')

plt.xticks(X_axis, ReliaData.index.values, fontsize = 30)
plt.xlabel("DATE", fontsize = 30,fontweight='bold')
plt.ylabel("ASAI", fontsize = 30,fontweight='bold')
plt.legend(loc="lower center", bbox_to_anchor=[0.5, -0.12],ncol=len(ReliaData.columns), shadow=False, title="LEGEND", fancybox=True, fontsize = 23)

plt.tick_params(labelsize=30,grid_linewidth=2)
major_tick = range(5,150, 5)
ax.set_yticks(major_tick) # Grid

plt.title("Figure 7: ASIA (Comparative Monthly Average Service Availability Index for the Study Period)", fontsize=35, y=-0.15)
plt.axis('tight')
plt.show()
